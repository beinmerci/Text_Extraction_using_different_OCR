# %%
#pip install google-cloud-vision
#https://cloud.google.com/docs/authentication/getting-started

# %%
## Set path for google credentials
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="E:\\GitHub\\OCR_TextExtraction\\GoogleKey\\key.json"

# %%
def detect_text(path):
    """Detects text in the file."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))

# %%
## Select Input image file for text extraction
from tkinter.filedialog import askopenfilename
detect_text(askopenfilename())
# Out:
# Texts:
#
# "Example Company
# Balance Sheet
# December 31, 2018
# ASSETS
# LIABILITIES
# Current liabilities
# Current assets
# Notes payable
# Accounts payable
# Wages payable
# Interest payable
# Taxes payable
# Warranty liability
# Unearned revenues
# 5,000
# Cash
# $
# 2,100
# $
# Petty cash
# Temporary investments
# Accounts receivable net
# Inventory
# Supplies
# Prepaid insurance
# 100
# 35,900
# 8,500
# 2,900
# 6,100
# 1,100
# 10,000
# 40,500
# 31,000
# 3,800
# 1,500
# 89,000
# 1,500
# 61.000
# Total current liabilities
# Total current assets
# Long-term liabil ities
# Notes payable
# Bonds payable
# Total long-term liabilities
# Investments
# 36,000
# 20,000
# Property, plant & equipment
# 400,000
# 420,000
# 5,500
# 6,500
# Land
# Land improvements
# Buildings
# 180,000
# 481.000
# Equipment
# 201,000
# Total liabilities
# Less: accum depreciation
# Prop, plant & equip net
# (56,000)
# 337,000
# STOCKHOLDERS' EQUITY
# Intangible assets
# Common stock
# Retained earnings
# Accum other comprehensive income
# Goodwill
# 105,000
# 110,000
# Trade names
# 200,000
# 305,000
# 220,000
# Total intangible assets
# 9,000
# Less: Treasury stock
# Total stockholders' equity
# (50,000)
# 289,000
# Other assets
# 3,000
# $ 770,000
# Total liabilities & stockholders' equity
# Total assets
# $770,000
# The notes to the sample balance sheet have been omitted.
# "
# bounds: (17,23),(613,23),(613,628),(17,628)
#
# "Example"
# bounds: (256,23),(308,23),(308,35),(256,35)
#
# "Company"
# bounds: (313,23),(371,23),(371,35),(313,35)
#
# "Balance"
# bounds: (270,39),(318,39),(318,48),(270,48)
#
# "Sheet"
# bounds: (324,39),(358,39),(358,48),(324,48)
#
# "December"
# bounds: (256,55),(317,55),(317,64),(256,64)
#
# "31,"
# bounds: (323,55),(338,55),(338,65),(323,65)
#
# "2018"
# bounds: (344,55),(371,55),(371,64),(344,64)
#
# "ASSETS"
# bounds: (17,83),(67,83),(67,93),(17,93)
#
# "LIABILITIES"
# bounds: (332,83),(408,84),(408,94),(332,93)
#
# "Current"
# bounds: (332,115),(372,115),(372,124),(332,124)
#
# "liabilities"
# bounds: (376,116),(421,116),(421,124),(376,124)
#
# "Current"
# bounds: (18,116),(58,116),(58,124),(18,124)
#
# "assets"
# bounds: (62,116),(96,116),(96,124),(62,124)
#
# "Notes"
# bounds: (340,131),(370,131),(370,140),(340,140)
#
# "payable"
# bounds: (376,131),(416,131),(416,142),(376,142)
#
# "Accounts"
# bounds: (340,147),(389,147),(389,155),(340,155)
#
# "payable"
# bounds: (394,147),(435,147),(435,157),(394,157)
#
# "Wages"
# bounds: (340,163),(376,163),(376,174),(340,174)
#
# "payable"
# bounds: (381,162),(422,162),(422,174),(381,174)
#
# "Interest"
# bounds: (340,178),(379,178),(379,187),(340,187)
#
# "payable"
# bounds: (384,178),(425,178),(425,190),(384,190)
#
# "Taxes"
# bounds: (340,194),(371,195),(371,203),(340,202)
#
# "payable"
# bounds: (376,193),(417,194),(417,206),(376,205)
#
# "Warranty"
# bounds: (340,209),(387,208),(387,221),(340,222)
#
# "liability"
# bounds: (392,209),(427,208),(427,221),(392,222)
#
# "Unearned"
# bounds: (340,225),(392,226),(392,235),(340,234)
#
# "revenues"
# bounds: (397,226),(446,227),(446,235),(397,234)
#
# "5,000"
# bounds: (580,131),(609,130),(609,140),(580,141)
#
# "Cash"
# bounds: (26,132),(53,132),(53,140),(26,140)
#
# "$"
# bounds: (242,132),(247,132),(247,140),(242,140)
#
# "2,100"
# bounds: (267,132),(296,132),(296,141),(267,141)
#
# "$"
# bounds: (557,132),(562,132),(562,141),(557,141)
#
# "Petty"
# bounds: (26,147),(52,147),(52,157),(26,157)
#
# "cash"
# bounds: (57,147),(81,147),(81,156),(57,156)
#
# "Temporary"
# bounds: (26,163),(82,162),(82,173),(26,174)
#
# "investments"
# bounds: (87,163),(150,162),(150,171),(87,172)
#
# "Accounts"
# bounds: (25,178),(74,177),(74,187),(25,188)
#
# "receivable"
# bounds: (79,178),(133,177),(133,187),(79,188)
#
# "net"
# bounds: (138,179),(161,179),(161,188),(138,188)
#
# "Inventory"
# bounds: (26,193),(74,192),(74,204),(26,205)
#
# "Supplies"
# bounds: (26,210),(71,210),(71,221),(26,221)
#
# "Prepaid"
# bounds: (26,225),(66,225),(66,235),(26,235)
#
# "insurance"
# bounds: (72,226),(123,227),(123,235),(72,234)
#
# "100"
# bounds: (278,148),(296,148),(296,156),(278,156)
#
# "35,900"
# bounds: (574,148),(609,148),(609,157),(574,157)
#
# "8,500"
# bounds: (580,163),(609,161),(610,171),(581,173)
#
# "2,900"
# bounds: (580,178),(609,177),(609,187),(580,188)
#
# "6,100"
# bounds: (580,194),(609,194),(609,204),(580,204)
#
# "1,100"
# bounds: (581,210),(609,209),(609,219),(581,220)
#
# "10,000"
# bounds: (261,162),(296,161),(296,172),(261,173)
#
# "40,500"
# bounds: (260,179),(296,178),(296,187),(260,188)
#
# "31,000"
# bounds: (260,194),(296,194),(296,203),(260,203)
#
# "3,800"
# bounds: (267,209),(295,208),(295,218),(267,219)
#
# "1,500"
# bounds: (268,225),(295,224),(295,234),(268,235)
#
# "89,000"
# bounds: (256,238),(296,238),(296,253),(256,253)
#
# "1,500"
# bounds: (576,226),(609,226),(609,238),(576,238)
#
# "61.000"
# bounds: (568,238),(609,238),(609,254),(568,254)
#
# "Total"
# bounds: (344,238),(370,238),(370,254),(344,254)
#
# "current"
# bounds: (377,242),(414,242),(414,249),(377,249)
#
# "liabilities"
# bounds: (418,241),(463,241),(463,249),(418,249)
#
# "Total"
# bounds: (34,241),(58,241),(58,250),(34,250)
#
# "current"
# bounds: (63,242),(100,242),(100,250),(63,250)
#
# "assets"
# bounds: (104,242),(138,242),(138,250),(104,250)
#
# "Long-term"
# bounds: (333,273),(386,272),(386,283),(333,284)
#
# "liabil"
# bounds: (391,273),(413,273),(413,281),(391,281)
#
# "ities"
# bounds: (416,272),(436,272),(436,281),(416,281)
#
# "Notes"
# bounds: (341,288),(371,289),(371,298),(341,297)
#
# "payable"
# bounds: (376,287),(417,288),(417,299),(376,298)
#
# "Bonds"
# bounds: (340,303),(374,304),(374,313),(340,312)
#
# "payable"
# bounds: (378,303),(419,304),(419,316),(378,315)
#
# "Total"
# bounds: (349,319),(373,319),(373,328),(349,328)
#
# "long-term"
# bounds: (378,320),(428,320),(428,329),(378,329)
#
# "liabilities"
# bounds: (433,320),(478,320),(478,328),(433,328)
#
# "Investments"
# bounds: (18,272),(82,274),(82,284),(18,282)
#
# "36,000"
# bounds: (260,272),(296,271),(296,281),(260,282)
#
# "20,000"
# bounds: (574,289),(609,289),(609,298),(574,298)
#
# "Property,"
# bounds: (18,304),(64,305),(64,316),(18,315)
#
# "plant"
# bounds: (70,304),(95,304),(95,315),(70,315)
#
# "&"
# bounds: (100,304),(106,304),(106,312),(100,312)
#
# "equipment"
# bounds: (111,304),(167,305),(167,316),(111,315)
#
# "400,000"
# bounds: (567,304),(609,305),(609,317),(567,316)
#
# "420,000"
# bounds: (561,316),(609,316),(609,332),(561,332)
#
# "5,500"
# bounds: (267,319),(296,318),(296,328),(267,329)
#
# "6,500"
# bounds: (267,335),(296,334),(296,344),(267,345)
#
# "Land"
# bounds: (26,320),(51,320),(51,328),(26,328)
#
# "Land"
# bounds: (26,335),(51,335),(51,344),(26,344)
#
# "improvements"
# bounds: (57,335),(132,336),(132,347),(57,346)
#
# "Buildings"
# bounds: (26,350),(74,352),(73,363),(25,361)
#
# "180,000"
# bounds: (254,351),(296,350),(296,359),(254,360)
#
# "481.000"
# bounds: (567,366),(610,367),(610,380),(567,379)
#
# "Equipment"
# bounds: (26,367),(83,367),(83,376),(26,376)
#
# "201,000"
# bounds: (253,367),(296,367),(296,376),(253,376)
#
# "Total"
# bounds: (332,367),(356,367),(356,375),(332,375)
#
# "liabilities"
# bounds: (361,367),(406,367),(406,375),(361,375)
#
# "Less:"
# bounds: (26,383),(53,383),(53,391),(26,391)
#
# "accum"
# bounds: (58,385),(93,385),(93,391),(58,391)
#
# "depreciation"
# bounds: (98,383),(162,383),(162,393),(98,393)
#
# "Prop,"
# bounds: (33,398),(60,398),(60,407),(33,407)
#
# "plant"
# bounds: (65,396),(91,396),(91,407),(65,407)
#
# "&"
# bounds: (95,397),(101,397),(101,408),(95,408)
#
# "equip"
# bounds: (107,398),(135,398),(135,408),(107,408)
#
# "net"
# bounds: (140,399),(163,399),(163,406),(140,406)
#
# "(56,000)"
# bounds: (246,383),(300,383),(300,394),(246,394)
#
# "337,000"
# bounds: (249,398),(296,398),(296,410),(249,410)
#
# "STOCKHOLDERS'"
# bounds: (328,425),(443,426),(443,442),(328,441)
#
# "EQUITY"
# bounds: (445,426),(491,426),(491,442),(445,442)
#
# "Intangible"
# bounds: (18,430),(69,430),(69,440),(18,440)
#
# "assets"
# bounds: (74,430),(108,430),(108,438),(74,438)
#
# "Common"
# bounds: (340,460),(388,461),(388,471),(340,470)
#
# "stock"
# bounds: (393,460),(420,461),(420,471),(393,470)
#
# "Retained"
# bounds: (340,476),(387,476),(387,485),(340,485)
#
# "earnings"
# bounds: (392,476),(438,476),(438,487),(392,487)
#
# "Accum"
# bounds: (340,492),(375,492),(375,500),(340,500)
#
# "other"
# bounds: (381,492),(407,492),(407,500),(381,500)
#
# "comprehensive"
# bounds: (412,487),(493,487),(493,502),(412,502)
#
# "income"
# bounds: (498,492),(536,492),(536,500),(498,500)
#
# "Goodwill"
# bounds: (26,460),(71,459),(71,469),(26,470)
#
# "105,000"
# bounds: (254,461),(296,461),(296,470),(254,470)
#
# "110,000"
# bounds: (569,461),(609,461),(609,470),(569,470)
#
# "Trade"
# bounds: (26,476),(56,476),(56,485),(26,485)
#
# "names"
# bounds: (61,478),(96,478),(96,485),(61,485)
#
# "200,000"
# bounds: (253,477),(296,477),(296,486),(253,486)
#
# "305,000"
# bounds: (249,489),(296,489),(296,501),(249,501)
#
# "220,000"
# bounds: (567,477),(609,476),(609,485),(567,486)
#
# "Total"
# bounds: (33,492),(57,492),(57,500),(33,500)
#
# "intangible"
# bounds: (62,491),(113,492),(113,503),(62,502)
#
# "assets"
# bounds: (118,492),(152,493),(152,502),(118,501)
#
# "9,000"
# bounds: (580,492),(609,492),(609,502),(580,502)
#
# "Less:"
# bounds: (340,508),(367,508),(367,516),(340,516)
#
# "Treasury"
# bounds: (372,508),(418,508),(418,518),(372,518)
#
# "stock"
# bounds: (424,508),(451,508),(451,516),(424,516)
#
# "Total"
# bounds: (348,523),(372,523),(372,532),(348,532)
#
# "stockholders'"
# bounds: (377,524),(446,524),(446,532),(377,532)
#
# "equity"
# bounds: (451,524),(482,524),(482,534),(451,534)
#
# "(50,000)"
# bounds: (564,508),(613,508),(613,520),(564,520)
#
# "289,000"
# bounds: (561,520),(610,520),(610,533),(561,533)
#
# "Other"
# bounds: (18,523),(47,523),(47,532),(18,532)
#
# "assets"
# bounds: (52,524),(86,524),(86,532),(52,532)
#
# "3,000"
# bounds: (267,524),(296,524),(296,533),(267,533)
#
# "$"
# bounds: (557,555),(562,555),(562,564),(557,564)
#
# "770,000"
# bounds: (567,553),(610,554),(610,566),(567,565)
#
# "Total"
# bounds: (332,555),(356,555),(356,563),(332,563)
#
# "liabilities"
# bounds: (361,555),(406,555),(406,563),(361,563)
#
# "&"
# bounds: (411,554),(417,554),(417,563),(411,563)
#
# "stockholders'"
# bounds: (423,554),(492,554),(492,564),(423,564)
#
# "equity"
# bounds: (496,555),(527,555),(527,564),(496,564)
#
# "Total"
# bounds: (18,555),(42,555),(42,563),(18,563)
#
# "assets"
# bounds: (47,555),(81,555),(81,564),(47,564)
#
# "$770,000"
# bounds: (243,555),(296,555),(296,566),(243,566)
#
# "The"
# bounds: (17,617),(37,617),(37,625),(17,625)
#
# "notes"
# bounds: (42,618),(70,618),(70,625),(42,625)
#
# "to"
# bounds: (75,618),(83,618),(83,625),(75,625)
#
# "the"
# bounds: (88,617),(104,617),(104,625),(88,625)
#
# "sample"
# bounds: (109,617),(147,617),(147,628),(109,628)
#
# "balance"
# bounds: (152,617),(193,617),(193,626),(152,626)
#
# "sheet"
# bounds: (198,617),(226,617),(226,625),(198,625)
#
# "have"
# bounds: (231,617),(256,617),(256,625),(231,625)
#
# "been"
# bounds: (261,617),(286,617),(286,626),(261,626)
#
# "omitted."
# bounds: (291,617),(332,617),(332,626),(291,626)
